# %% [markdown]
#  # Libraries and functions

# %%
pip install pyreadr pandas seaborn matplotlib
# Out:
# Collecting pyreadr
#   Downloading pyreadr-0.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (3.10.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pyreadr-0.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (413 kB)
# Installing collected packages: pyreadr
# Successfully installed pyreadr-0.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pyreadr

# %%
def load_rda(file_paths):

  dataframes = {}

  for file_path in file_paths:
      result = pyreadr.read_r(file_path)

      for key in result.keys():
          dataframes[key] = result[key]

  return dataframes

# %%
def outlier_values(df):
    outliers = pd.Series(dtype="float64")

    for col in df.select_dtypes(include=["number"]):  
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        mask = (df[col] < (Q1 - 1.5 * IQR)) | (df[col] > (Q3 + 1.5 * IQR))
        outliers[col] = mask.mean() * 100  
    return outliers

# %%
def missing_values(df):
  return(df.isnull().sum())

# %%
def plot_variable_distributions(dataframe, output_dir="plots"):
#   import os

#   # Créer le répertoire si nécessaire
#   os.makedirs(output_dir, exist_ok=True)

  # Variables numériques
  for column in dataframe.select_dtypes(include='number').columns:
      plt.figure(figsize=(10, 6))
      sns.histplot(dataframe[column], kde=True, color="blue", stat = 'percent')
      plt.title(f"Distribution de {column}")
      plt.xlabel(column)
      plt.ylabel("Pourcentage")
      # plt.savefig(f"{output_dir}/distribution_{column}.png")
      # plt.close()
      plt.show()

  # Variables catégoriques
  for column in dataframe.select_dtypes(include='category').columns:
      plt.figure(figsize=(10, 6))
      sns.countplot(y=dataframe[column], order=dataframe[column].value_counts().index, stat='percent')
      plt.title(f"Distribution de {column}")
      plt.xlabel("Pourcentage")
      plt.ylabel(column)
      # plt.savefig(f"{output_dir}/distribution_{column}.png")
      # plt.close()
      plt.show()

# %%
def plot_boxplots(df):
    numeric_columns = df.select_dtypes(include='number').columns
    plt.figure(figsize=(15, 10))

    # Créer un boxplot pour chaque variable numérique
    for i, col in enumerate(numeric_columns, 1):
        plt.subplot(4, 4, i)
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot de {col}')

    plt.tight_layout()
    plt.show()

# %%
def clean_data(data_dict):
    cleaned_dict = {}
    for key, df in data_dict.items():
        df_cleaned = df.drop_duplicates()
        if 'RecordBeg' in df_cleaned.columns:
            df_cleaned.loc[:, 'RecordBeg'] = pd.to_datetime(df_cleaned['RecordBeg'], errors='coerce')
        if 'RecordEnd' in df_cleaned.columns:
            df_cleaned.loc[:, 'RecordEnd'] = pd.to_datetime(df_cleaned['RecordEnd'], errors='coerce')

        cleaned_dict[key] = df_cleaned

    return cleaned_dict

# %% [markdown]
#  # Load freMPL files into one

# %%
file_paths = ['freMPL1.rda','freMPL2.rda','freMPL3.rda','freMPL4.rda','freMPL5.rda',
              'freMPL6.rda','freMPL7.rda','freMPL8.rda','freMPL9.rda','freMPL10.rda']

# %%
file_paths = [f'/home/onyxia/work/Federated_Learning_Milliman/raw_data/{file}' for file in file_paths]

# %%
df = load_rda(file_paths)
df1 = clean_data(df)
# Out:
# /opt/conda/lib/python3.12/site-packages/pyreadr/_pyreadr_parser.py:233: RuntimeWarning: invalid value encountered in cast
#   df[colname] = df[colname].values.astype("datetime64[D]").astype(datetime)
# /opt/conda/lib/python3.12/site-packages/pyreadr/_pyreadr_parser.py:233: RuntimeWarning: invalid value encountered in cast
#   df[colname] = df[colname].values.astype("datetime64[D]").astype(datetime)
# /opt/conda/lib/python3.12/site-packages/pyreadr/_pyreadr_parser.py:233: RuntimeWarning: invalid value encountered in cast
#   df[colname] = df[colname].values.astype("datetime64[D]").astype(datetime)
# /opt/conda/lib/python3.12/site-packages/pyreadr/_pyreadr_parser.py:233: RuntimeWarning: invalid value encountered in cast
#   df[colname] = df[colname].values.astype("datetime64[D]").astype(datetime)
# /opt/conda/lib/python3.12/site-packages/pyreadr/_pyreadr_parser.py:233: RuntimeWarning: invalid value encountered in cast
#   df[colname] = df[colname].values.astype("datetime64[D]").astype(datetime)
# /opt/conda/lib/python3.12/site-packages/pyreadr/_pyreadr_parser.py:233: RuntimeWarning: invalid value encountered in cast
#   df[colname] = df[colname].values.astype("datetime64[D]").astype(datetime)
# /opt/conda/lib/python3.12/site-packages/pyreadr/_pyreadr_parser.py:233: RuntimeWarning: invalid value encountered in cast
#   df[colname] = df[colname].values.astype("datetime64[D]").astype(datetime)
# /opt/conda/lib/python3.12/site-packages/pyreadr/_pyreadr_parser.py:233: RuntimeWarning: invalid value encountered in cast
#   df[colname] = df[colname].values.astype("datetime64[D]").astype(datetime)
# /opt/conda/lib/python3.12/site-packages/pyreadr/_pyreadr_parser.py:233: RuntimeWarning: invalid value encountered in cast
#   df[colname] = df[colname].values.astype("datetime64[D]").astype(datetime)
# /opt/conda/lib/python3.12/site-packages/pyreadr/_pyreadr_parser.py:233: RuntimeWarning: invalid value encountered in cast
#   df[colname] = df[colname].values.astype("datetime64[D]").astype(datetime)

# %%
freMPL_final = pd.concat(df1, ignore_index=True)
freMPL_final_cleaned = freMPL_final.dropna(axis=1)#on enlève les colonnes avec des NA

# %%
freMPL_final_cleaned['LicAge'] = freMPL_final_cleaned['LicAge']/12
# Out:
# /tmp/ipykernel_72310/1192033273.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   freMPL_final_cleaned['LicAge'] = freMPL_final_cleaned['LicAge']/12

# %%
freMPL_final_cleaned.to_csv('freMPL.csv',index=False)

# %%
freMPL_final_cleaned
# Out:
#         Exposure     LicAge            RecordBeg  Gender MariStat SocioCateg  \
# 0          0.583  30.500000  2004-06-01 00:00:00  Female    Other       CSP1
# 1          0.200  15.583333  2004-10-19 00:00:00    Male    Alone      CSP55
# 2          0.083  14.083333  2004-07-16 00:00:00  Female    Other       CSP1
# 3          0.375  14.166667  2004-08-16 00:00:00  Female    Other       CSP1
# 4          0.500  18.666667  2004-01-01 00:00:00    Male    Other      CSP47
# ...          ...        ...                  ...     ...      ...        ...
# 243060     0.217  22.583333  2004-10-13 00:00:00    Male    Other      CSP50
# 243061     0.225  48.583333  2004-10-10 00:00:00    Male    Other      CSP60
# 243062     0.510  42.750000  2004-01-01 00:00:00    Male    Other      CSP60
# 243063     0.833  63.666667  2004-03-01 00:00:00    Male    Other      CSP60
# 243064     0.344  22.000000  2004-04-01 00:00:00  Female    Other      CSP50
#
#                       VehUsage  DrivAge  HasKmLimit  BonusMalus  ClaimAmount  \
# 0                 Professional       55           0          72     0.000000
# 1       Private+trip to office       34           0          80     0.000000
# 2                 Professional       33           0          63     0.000000
# 3                 Professional       34           0          63     0.000000
# 4                 Professional       53           0          72  1418.610272
# ...                        ...      ...         ...         ...          ...
# 243060            Professional       40           0          50     0.000000
# 243061                 Private       67           0          50     0.000000
# 243062                 Private       65           0          62     0.000000
# 243063                 Private       83           0          50     0.000000
# 243064  Private+trip to office       40           0          50     0.000000
#
#         ClaimInd
# 0              0
# 1              0
# 2              0
# 3              0
# 4              1
# ...          ...
# 243060         0
# 243061         0
# 243062         0
# 243063         0
# 243064         0
#
# [243065 rows x 12 columns]

# %%
freMPL_final_cleaned.dtypes
# Out:
# Exposure        float64
# LicAge          float64
# RecordBeg        object
# Gender         category
# MariStat       category
# SocioCateg       object
# VehUsage       category
# DrivAge           int32
# HasKmLimit        int32
# BonusMalus        int32
# ClaimAmount     float64
# ClaimInd          int32
# dtype: object

# %% [markdown]
# # Etude statistique de la base

# %%
freMPL = pd.read_csv('data_comparaison/freMPL.csv')

# %%
freMPL = freMPL.astype({col: 'category' for col in freMPL.select_dtypes(include='object').columns})

# %%
freMPL.head()
# Out:
#    Exposure     LicAge            RecordBeg  Gender MariStat SocioCateg  \
# 0     0.583  30.500000  2004-06-01 00:00:00  Female    Other       CSP1
# 1     0.200  15.583333  2004-10-19 00:00:00    Male    Alone      CSP55
# 2     0.083  14.083333  2004-07-16 00:00:00  Female    Other       CSP1
# 3     0.375  14.166667  2004-08-16 00:00:00  Female    Other       CSP1
# 4     0.500  18.666667  2004-01-01 00:00:00    Male    Other      CSP47
#
#                  VehUsage  DrivAge  HasKmLimit  BonusMalus  ClaimAmount  \
# 0            Professional       55           0          72     0.000000
# 1  Private+trip to office       34           0          80     0.000000
# 2            Professional       33           0          63     0.000000
# 3            Professional       34           0          63     0.000000
# 4            Professional       53           0          72  1418.610272
#
#    ClaimInd
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1

# %%
outlier_values(freMPL)
# Out:
# Exposure        0.000000
# LicAge          0.081871
# DrivAge         0.042787
# HasKmLimit     11.472651
# BonusMalus      2.245078
# ClaimAmount     7.155699
# ClaimInd        6.542694
# dtype: float64

# %%
plot_variable_distributions(freMPL)

# %%
plot_boxplots(freMPL)

# %%
freMPL.dtypes
# Out:
# Exposure        float64
# LicAge          float64
# RecordBeg      category
# Gender         category
# MariStat       category
# SocioCateg     category
# VehUsage       category
# DrivAge           int64
# HasKmLimit        int64
# BonusMalus        int64
# ClaimAmount     float64
# ClaimInd          int64
# dtype: object

# %% [markdown]
# ## Etude plus approndi

# %%
plt.figure(figsize=(10, 6))

sns.histplot(
    freMPL["DrivAge"], bins=84, kde=True, stat="percent", 
    color="royalblue", edgecolor="black", alpha=0.7
)
#Legende
plt.title("Distribution des âges des conducteurs", fontsize=14, fontweight='bold')
plt.xlabel("Âge du conducteur", fontsize=12)
plt.ylabel("Pourcentage (%)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.histplot(
    freMPL["LicAge"], kde=True, stat="percent", 
    color="royalblue", edgecolor="black", alpha=0.7
)
#Legende
plt.title("Distribution des âges des permis", fontsize=14, fontweight='bold')
plt.xlabel("Âge du permis", fontsize=12)
plt.ylabel("Pourcentage (%)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.histplot(
    freMPL["Exposure"], bins = 100, kde=True, stat="percent", 
    color="royalblue", edgecolor="black", alpha=0.7
)
#Legende
plt.title("Distribution de l'Exposure", fontsize=14, fontweight='bold')
plt.xlabel("Exposure", fontsize=12)
plt.ylabel("Pourcentage (%)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.histplot(
    freMPL["BonusMalus"], bins = range(0,400,100), kde=False, stat="percent", 
    color="royalblue", edgecolor="black", alpha=0.7
)
#Legende
plt.title("Distribution de BonusMalus", fontsize=14, fontweight='bold')
plt.xlabel("BonusMalus", fontsize=12)
plt.ylabel("Pourcentage (%)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.xticks(fontsize=10)
plt.yticks(range(0,100,5),fontsize=10)

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.countplot(
    y=freMPL["ClaimInd"],
    order=freMPL["ClaimInd"].value_counts().index,
    hue=freMPL["ClaimInd"],
    palette="pastel",
    edgecolor="black",
    stat = "percent",
)
#Legende
plt.title("Distribution de ClaimInd", fontsize=14, fontweight='bold')
plt.xlabel("ClaimInd", fontsize=12)
plt.ylabel("Pourcentage (%)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.xticks(ticks=range(0, 101, 5), fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %%
has_claim = freMPL[freMPL["ClaimInd"] > 0]

bins = [0, 500, 1500, 5000, 20000, float('inf')]
labels = ["Légers sinistres", "Sinistres modérés", "Sinistres importants", "Sinistres graves", "Sinistres très graves"]

has_claim["Gravité du sinistre"] = pd.cut(has_claim["ClaimAmount"], bins=bins, labels=labels, right=False)

plt.figure(figsize=(10, 6))

sns.countplot(
    y=has_claim["Gravité du sinistre"],
    order=has_claim["Gravité du sinistre"].value_counts().index,
    palette="pastel", 
    edgecolor="black",
    hue=has_claim["Gravité du sinistre"]
)

#Legende
plt.title("Répartition des sinistres par gravité", fontsize=14, fontweight='bold')
plt.xlabel("Nombre de sinistres", fontsize=12)
plt.ylabel("Gravité du sinistre", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='x', linestyle='--', alpha=0.6)

plt.show()
# Out:
# /tmp/ipykernel_3001/2020927521.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   has_claim["Gravité du sinistre"] = pd.cut(has_claim["ClaimAmount"], bins=bins, labels=labels, right=False)

# %%
plt.figure(figsize=(10, 6))

sns.countplot(
    y=freMPL["HasKmLimit"],
    order=freMPL["HasKmLimit"].value_counts().index,
    hue=freMPL["HasKmLimit"],
    palette="pastel",
    edgecolor="black",
    stat = "percent",
)
#Legende
plt.title("Distribution de HasKmLimit", fontsize=14, fontweight='bold')
plt.xlabel("Pourcentage", fontsize=12)
plt.ylabel("HasKmLimit", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.xticks(ticks=range(0, 101, 10), fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %%
has_claim['ClaimAmount'].mean()
# Out:
# np.float64(2100.809534063477)

# %%
freMPL.describe().round(2)
# Out:
#         Exposure     LicAge    DrivAge  HasKmLimit  BonusMalus  ClaimAmount  \
# count  243065.00  243065.00  243065.00   243065.00   243065.00    243065.00
# mean        0.44      25.87      47.37        0.11       62.24       134.19
# std         0.29      13.58      15.12        0.32       17.67      2138.34
# min         0.00       0.00      18.00        0.00       50.00     -3407.70
# 25%         0.18      14.42      35.00        0.00       50.00         0.00
# 50%         0.42      25.00      46.00        0.00       50.00         0.00
# 75%         0.67      36.08      58.00        0.00       72.00         0.00
# max         1.00      78.33     103.00        1.00      272.00    802620.27
#
#         ClaimInd
# count  243065.00
# mean        0.07
# std         0.25
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         1.00

# %%
freMPL.describe(include = 'category')
# Out:
#                   RecordBeg  Gender MariStat SocioCateg  \
# count                243065  243065   243065     243065
# unique                  366       2        2         61
# top     2004-01-01 00:00:00    Male    Other      CSP50
# freq                  94418  152820   194062     131599
#
#                       VehUsage
# count                   243065
# unique                       4
# top     Private+trip to office
# freq                    119201

# %% [markdown]
# # Résumé
#
# Exposure: pic tous les 0.8 exposure( correspond à 1 mois, la durée d'exposition se termine généralement à peu près le même jour que celui du début)
#
# LicAge(age du permis): sensiblement même allure que DrivAge mais avec un pic supplémentaire
#
# RecordBeg : début du contrat, inutile
#
# Gender: environ 60% homme 40% femme
#
# MariStat: Majorité autre
#
# SocioCateg: majorité d'employé(CSP50)
#
# VehUsage: majorité de véhicule pour usage privé et aller au travail
#
# DrivAge : pic d'age pour la trentaine et 55 ans, baisse drastique ensuite pour les personnes plus agées
#
# HasKmLimit: 10% ont une limite
#
# BonusMalus: très grande majorité <100 (95%) c'est-à-dire en bonus
#
# ClaimAmount: moyenne de 134, 2100 avec que les sinistres
#
# ClaimInd: environ 6% de claim de sinistre

# %%
claim_stats = freMPL.groupby('ClaimInd').agg(
    average_LicAge=('LicAge', 'mean'),
    count=('LicAge', 'size')
).sort_values(by='average_LicAge', ascending=False)

# %%
print(claim_stats)
# Out:
#           average_LicAge   count  gender_count
# ClaimInd
# 0              25.923345  227162        227162
# 1              25.055566   15903         15903

# %%
L = freMPL.groupby('ClaimInd')['Gender'].value_counts().unstack(fill_value=0)

# %%
L.div(L.sum(axis=1),axis=0)
# Out:
# Gender      Female      Male
# ClaimInd
# 0         0.371149  0.628851
# 1         0.373137  0.626863
